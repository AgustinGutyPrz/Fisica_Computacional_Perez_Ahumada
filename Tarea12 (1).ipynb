# %% [markdown]
# __Ejercicio 1:__. Implementar método implicito de Euler como quieran.

# %%
function eulerMethod(f,alfa,t0,h,N) #voy a implementar el metodo numerico de euler para ec. diferenciales
    T = [] #en estos arreglos vacios guardaré mis pasos de tiempo t
    W = []#aqui guardare los x obtenidos en cada iteracion
    t=t0 #es mi valor inicial de t
    w = alfa #es mi valor inicial de x
    while t<=N #si t aun no llega al valor que quiero que llegue, entra al ciclo
        push!(T,t) #guarda el valor de t en T
        push!(W,w) #guarda el valor de x en W
        t=t+h
        s=f(w,t)#la ec diferencial de primer orden está igualada a una funcion f y aca se evalua nuestro valor anterior de t y x
        w = w + h*s #recalculamos x
        
    end  
    scatter(T,W,color="green") #graficamos t vs x
end
# Out:
# eulerMethod (generic function with 1 method)

# %%
function h(t,x) #En este ejemplo será el de la tarea pasada
    return -5*x
end
# Out:
# h (generic function with 1 method)

# %%
using PyPlot

# %%
eulerMethod(h,2,0,0.01,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f931a218ad0>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f931a189310>

# %% [markdown]
# __Ejercicio 2:__ Implementar Euler: Regla del punto medio.

# %%
function EulerPuntoMedio(f,alfa,t0,h,N)
    X=[] #lo mismo que para EulerMethod
    T=[]
    x=alfa
    t=t0
    while t<=N
        push!(X,x)
        push!(T,t)
        a=f(t,x) #aca debo calcular el valor de esa f a la que esta igualada la ec evaluada en el valor anterior de x y t, pero a diferencia del otro método; aca no va a ir sumado directamente
        tt=t+(h/2) #recalculo una nueva t, tt que es el valor anterior de t mas la mitad del tamaño de paso
        xx=x+(h*a/2) #recalculo una nueva x,xx que es el valor de x mas el valor de a (f evaluado en x y t anteriores) por la mitad del tamaño de paso
        A=f(tt,xx) #A es la nueva evaluacion en f, pero ahora con los t y x ficticios; tt y xx
        x=x+(h*A) #ahora si para calcular la nueva x, tomo x anterior y la suma por la nueva evalucion de f por h
        t=t+h #voy dando pasos de tiempo
    end
    scatter(T,X,color="red") #grafico mi aproximacion de t vs x
end
# Out:
# EulerPuntoMedio (generic function with 1 method)

# %%
EulerPuntoMedio(h,2,0,0.01,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb55b21d0>)
# PyObject <matplotlib.collections.PathCollection object at 0x7fdcb54ce890>

# %% [markdown]
# __Ejercicio 3:__ Implementar método de Runge-Kutta de orden 4.

# %%
function MetodoRunge(f,alfa,t0,h,N) #función para la aproximación mediante el método runge de cuarto grado
    T = []
    X = []
    t = t0
    x = alfa
    while t<=N
        push!(T,t)
        push!(X,x)
        k1=(f(t,x)) #K1,k2,k3,k4 son las fórmulas para calcular las constantes para el método
        k2=(f(t+(h/2),x+(h*k1/2)))#runge de 4 grado.
        k3=f(t+(h/2),x+(h*k2/2))
        k4=f(t+h,x+(h*k3))
        t=t+h #son los pasos de tiempo y es válido ya que son constantes.
        x= x + (h/6)*(k1+(2(k2+k3))+k4) #Es según la fórmula, una aproximación del método de runge
    end
    scatter(T,X,color="brown") #grafico t vs x
end
# Out:
# MetodoRunge (generic function with 1 method)

# %%
MetodoRunge(h,2,0,0.01,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb54683d0>)
# PyObject <matplotlib.collections.PathCollection object at 0x7fdcb534f610>

# %%
function comparacion(f,alfa,t0,h,N)
    eulerMethod(f,alfa,t0,h,N)
    MetodoRunge(f,alfa,t0,h,N)
    EulerPuntoMedio(f,alfa,t0,h,N)
end
# Out:
# comparacion (generic function with 1 method)

# %%
comparacion(h,2,0,0.01,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb55f9e50>)
# PyObject <matplotlib.collections.PathCollection object at 0x7fdcb52ac190>

# %% [markdown]
# Con fines de ver como se aproxima cada uno; lo voy a graficar con la solución para esta funcion específica para ver cual se acerca más y con h más pequeñas.

# %%
comparacion(h,2,0,0.1,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb52194d0>)
# PyObject <matplotlib.collections.PathCollection object at 0x7fdcb5031790>

# %%
comparacion(h,2,0,0.25,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb50f3310>)
# PyObject <matplotlib.collections.PathCollection object at 0x7fdcb4f03f50>

# %%
function comparacionconreal(alfa,t0,N,h) #aqui debo aclarar que es la grafica de t vs el valor de la solucion real de la f dada; en este caso el valor de f que propuse (funcion h), tiene la solucion alpha*e^(-5t) por eso puse esa función; pero en si es comparada con la solucion real de la ec dif
    T=[]
    X=[]
    t=t0
    x=alfa
    while t<=N
        push!(T,t)
        push!(X,x)
        t=t+h
        x=alfa*(exp(-5*t))
    end
    plot(T,X,color="gold")
end
# Out:
# comparacionconreal (generic function with 1 method)

# %%
comparacionconreal(2,0,8,0.01)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb4f93fd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcb4e4b250>

# %%
function comp1(f,alfa,t0,h,N)
    eulerMethod(f,alfa,t0,h,N)
    comparacionconreal(alfa,t0,N,h)
end
# Out:
# comp1 (generic function with 1 method)

# %%
function comp2(f,alfa,t0,h,N)
    comparacionconreal(alfa,t0,N,h)
    EulerPuntoMedio(f,alfa,t0,h,N)
end
# Out:
# comp2 (generic function with 1 method)

# %%
function comp3(f,alfa,t0,h,N)
    comparacionconreal(alfa,t0,N,h)
   MetodoRunge(f,alfa,t0,h,N)
end
# Out:
# comp3 (generic function with 1 method)

# %%
comp1(h,2,0,0.1,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb4ca9c10>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcb4c31550>

# %%
comp2(h,2,0,0.1,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb4b89dd0>)
# PyObject <matplotlib.collections.PathCollection object at 0x7fdcb4b78e50>

# %%
comp3(h,2,0,0.1,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb4ad2f90>)
# PyObject <matplotlib.collections.PathCollection object at 0x7fdcb4a57910>

# %% [markdown]
# En mi consideración y despues de comparar los 3 métodos me parece que una mejor aproximación es la de Runge Kutta orden 4. Pero igual se podría programar una comparacion global para verlo mejor.

# %%
function comparacionglobal(f,alfa,t0,h,N)
    eulerMethod(f,alfa,t0,h,N)
    MetodoRunge(f,alfa,t0,h,N)
    EulerPuntoMedio(f,alfa,t0,h,N)
    comparacionconreal(alfa,t0,N,h)
end
# Out:
# comparacionglobal (generic function with 1 method)

# %%
comparacionglobal(h,2,0,0.01,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb4a2fc50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcb49baa90>

# %%
comparacionglobal(h,2,0,0.05,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb4a1c110>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcb4899990>

# %%
comparacionglobal(h,2,0,0.1,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb4879150>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcb47f6890>

# %%
comparacionglobal(h,2,0,0.125,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb4758050>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcb46caf90>

# %% [markdown]
# Aqui ya es claro que la mejor aproximación es con RungeKutta y que si tenemos h suficientemente pequeñas; parece que todos se aproximan igual; pero RK es mejor porque con h más grandes (menos iteraciones) se tienen mejores aproximaciones.

# %%
comparacionglobal(h,2,0,0.001,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb46ae810>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcb462be50>

# %%
comparacionglobal(h,2,0,0.2,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdcb457ddd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fdcb457ac90>

# %% [markdown]
# __Ejercicio 5:__ Repita el ejercicio 1 del notebook anterior (Julia_6) y discuta los resultados respecto a lo que obtuvo con el método implícito.

# %%
function eulerMethodtarea11(f,alfa,t0,h,N)
    T = []
    W = []
    t=t0
    w = alfa
    j=(N/h)+1
    while t<=N
        push!(T,t)
        push!(W,w)
        s=f(w,t)
        w = w + h*s
        t=t+h
    end  
    scatter(T,W,color="blue")
end
# Out:
# eulerMethodtarea11 (generic function with 1 method)

# %%
function comparacion5(f,alfa,t0,h,N)
eulerMethodtarea11(f,alfa,t0,h,N) #es de color azul
    eulerMethod(f,alfa,t0,h,N) #es de color verde
end
# Out:
# comparacion5 (generic function with 1 method)

# %%
comparacion5(h,2,0,0.1,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f931a1696d0>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f931a0dc650>

# %%
comparacion5(h,2,0,0.01,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f931a0b2f10>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f931a030790>

# %%
comparacion5(h,2,0,0.5,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9319f84ed0>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f9319f008d0>

# %%
function j418(x,t)
    a=(2*x)-(18*t)
    b=(1+t)
    c=a/b
    return c
end
# Out:
# j418 (generic function with 1 method)

# %%
comparacion5(j418,4,0,0.1,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9319ec3810>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f9319e3af50>

# %%
comparacion5(j418,4,0,0.01,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9319e6b450>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f9319d85e10>

# %%
comparacion5(j418,4,0,0.005,8)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9319d539d0>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f9319ccdc50>

# %% [markdown]
# __Ejercicio 6:__ Usar el método del punto medio y de Runge-Kutta para resolver la ecuación: $$\frac{dx}{dt}=\frac{2x-18 t}{1+t}.$$ Compare su respuesta con la solución exacta: $4+8t-5t^2$. notén que $x(0)=4$.

# %%
function comparacion6(f,alfa,t0,h,N)
    EulerPuntoMedio(f,alfa,t0,h,N) #es de color rojo
    MetodoRunge(f,alfa,t0,h,N) #es de color cafe
end
# Out:
# comparacion6 (generic function with 1 method)

# %%
function j(t,x)
    a=(2*x)-(18*t)
    b=(1+t)
    c=a/b
    return c
end
# Out:
# j (generic function with 1 method)

# %%
comparacion6(j,4,0,0.1,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f931a40c950>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f931631e290>

# %%
comparacion6(j,4,0,0.5,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9319d49250>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f9316253550>

# %%
function comparacionSE(f,alfa,t0,h,N)
    EulerPuntoMedio(f,alfa,t0,h,N) #es de color rojo
    MetodoRunge(f,alfa,t0,h,N) #es de color cafe
    j=(N/h)+1
    xs = linspace(t0,N,j)
    ys = map(x -> 4+(8*x)-(5*(x^2)), xs)
    plot(xs,ys,color="yellow") #es la solución exacta y es de amarillo
end
# Out:
# comparacionSE (generic function with 1 method)

# %%
comparacionSE(j,4,0,0.1,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9319c7c550>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f9315fd4b10>

# %%
comparacionSE(j,4,0,0.5,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f93162d5dd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f9315d13b90>

# %%
comparacionSE(j,4,0,0.01,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9316213e90>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f9315c51810>

# %% [markdown]
# __Ejercicio 6:__ Grafique la energía total del oscilador harmonico usando los métodos explícito de Euler y Runge-Kutta de orden 4. Compare sus respuestas y discuta.

# %%
function oscilador(w,t,A,wo,yo)
    alp=wo*t
    bet=alp+yo
    c=wo*A*(cos(bet))
    return c
end
# Out:
# oscilador (generic function with 1 method)

# %%
function eulerMethodtarea126(f,alfa,t0,h,N)
    T = []
    W = []
    t=t0
    w = alfa
    j=(N/h)+1
    while t<=N
        push!(T,t)
        push!(W,w)
        s=f(t,w)
        w = w + h*s
        t=t+h
    end  
    scatter(T,W,color="blue")
    j=(N/h)+1
    xs = linspace(t0,N,j)
    ys = map(x ->(sin(2*x)), xs)
    plot(xs,ys,color="yellow") #es la solución exacta y es de amarillo
end
# Out:
# eulerMethodtarea126 (generic function with 2 methods)

# %%
using PyPlot

# %%
eulerMethodtarea126(oscilador,0,0,0.1,10,1,2,0)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f48b932de50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f48b92aef50>

# %%
function MetodoRunge126(f,alfa,t0,h,N) #función para la aproximación mediante el método runge de cuarto grado
    T = []
    X = []
    t = t0
    x = alfa
    while t<=N
        push!(T,t)
        push!(X,x)
        k1=(f(t,x)) #K1,k2,k3,k4 son las fórmulas para calcular las constantes para el método
        k2=(f(t+(h/2),x+(h*k1/2)))#runge de 4 grado.
        k3=f(t+(h/2),x+(h*k2/2))
        k4=f(t+h,x+(h*k3))
        t=t+h #son los pasos de tiempo y es válido ya que son constantes.
        x= x + (h/6)*(k1+(2(k2+k3))+k4) #Es según la fórmula, una aproximación del método de runge
    end
    scatter(T,X,color="brown") #grafico t vs x
        j=(N/h)+1
    xs = linspace(t0,N,j)
    ys = map(x ->(sin(2*x)), xs) #porque A=1 wo=2 yo=0, los puse fijos para evitar meterme en broncas con runge
    plot(xs,ys,color="yellow") #es la solución exacta y es de amarillo
end
# Out:
# MetodoRunge126 (generic function with 1 method)

# %%
function oscilafijo(t,x)
    c=2*(cos(2*t))
    return c
end
# Out:
# oscilafijo (generic function with 1 method)

# %%
MetodoRunge126(oscilafijo,0,0,0.1,100)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f48b9285f90>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f48b57198d0>

# %%
MetodoRunge126(oscilafijo,0,0,0.1,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f48b935d190>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f48b56558d0>

# %%
function comparacion126(f,alfa,t0,h,N)
    eulerMethodtarea126(f,alfa,t0,h,N)#va a ser los puntos azules
    MetodoRunge126(f,alfa,t0,h,N)#van a ser los puntos café
    #la linea amarilla es la solución exacta
end
# Out:
# comparacion126 (generic function with 1 method)

# %%
comparacion126(oscilafijo,0,0,0.1,20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f48b562afd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f48b547f490>

# %% [markdown]
# De nuevo podemos ver que es una mejor aproximación la de Runge Kuta.

# %% [markdown]
# __Ejercicio 7:__ Utilizando los métodos de Euler y Runge-Kutta con $h=0.01$ y una condición inicial, grafique las dos trayectorias en el espacio $(x,v)$ (esto casi es el espacio de fase en la mécanica clásica, para ello se necesitaria graficar $(x,p)$. Nota: Si ya tiene una forma de calcular $x$ y $v$ en forma de listas, digamos listx y listv, bastará con hacer plot(listx,listv).

# %%
comparacion126(oscilafijo,0,0,0.01,20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f48b53e0f90>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f48b5303c90>

# %% [markdown]
# __Ejercicio 8:__ Utilizando solo Runge-Kutta, grafique muchas condiciones iniciales del oscilador armónico en el espacio de fase. Tome todos los parámetros como prefiera, revisando que obtiene el resultado esperado.

# %%
function MetodoRunge128(f,alfa,t0,h,N) #función para la aproximación mediante el método runge de cuarto grado
    T = []
    X = []
    t = t0
    x = alfa
    while t<=N
        push!(T,t)
        push!(X,x)
        k1=(f(t,x)) #K1,k2,k3,k4 son las fórmulas para calcular las constantes para el método
        k2=(f(t+(h/2),x+(h*k1/2)))#runge de 4 grado.
        k3=f(t+(h/2),x+(h*k2/2))
        k4=f(t+h,x+(h*k3))
        t=t+h #son los pasos de tiempo y es válido ya que son constantes.
        x= x + (h/6)*(k1+(2(k2+k3))+k4) #Es según la fórmula, una aproximación del método de runge
    end
    scatter(T,X,color="brown") #grafico t vs x
        j=(N/h)+1
    xs = linspace(t0,N,j)
    ys = map(x ->(sin(2*x))+alfa, xs) #porque A=1 wo=2 yo=0, los puse fijos para evitar meterme en broncas con runge
    plot(xs,ys,color="yellow") #es la solución exacta y es de amarillo
end
# Out:
# MetodoRunge128 (generic function with 1 method)

# %%
MetodoRunge128(oscilafijo,3,0,0.01,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f48b4edff50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f48b4e73690>

# %%
MetodoRunge126(oscilafijo,3,0,0.01,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f48b4e32e90>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f48b4d3c750>

# %% [markdown]
# Se puede ver que a diferencia del anterior, aca tenemos que considerar una condición inicial; es decir; para la solución exacta le debemos sumar una constante que es la constante alfa (condición inicial) aca arriba se puede ver la comparación.

# %%
MetodoRunge128(oscilafijo,5,0,0.01,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f48b4d71bd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f48b4c7b450>

# %%
MetodoRunge128(oscilafijo,100,0,0.01,10)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f48b4ed6190>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f48b4bc3450>
